# %% [markdown]
# # install

# %%
from google.colab import drive

drive.mount("/content/gdrive")
dataset_dir = '/content/gdrive/MyDrive'

# %%
# !pip install -r /content/gdrive/MyDrive/IDQL_main/requirements.txt
# Out:
# ...
#   Cloning https://github.com/ikostrikov/dmcgym to /tmp/pip-install-_oxxa6da/dmcgym_48ac84c0466847e89eed391fc4935e64
#   Running command git clone --filter=blob:none --quiet https://github.com/ikostrikov/dmcgym /tmp/pip-install-_oxxa6da/dmcgym_48ac84c0466847e89eed391fc4935e64
#   Resolved https://github.com/ikostrikov/dmcgym to commit 777368ca3be4a635b54967111e5ca81ba6b18dbe
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached mujoco-py-1.50.1.68.tar.gz (120 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# ...
#   Created wheel for dmcgym: filename=dmcgym-0.0.1-py3-none-any.whl size=4343 sha256=0b1759cd1b545140e7b4c825bb2caa2f7f4bd9433dc90a16fc99993dba437066
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8zfb7q__/wheels/d7/a3/7c/133481d8cd2374fc217dc1f76abf553471fa7a5cc4c4ec0119
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
# ...

# %%
# !pip install gym tqdm absl-py ml-collections tensorboardX d4rl
# !pip install git+https://github.com/rail-berkeley/d4rl@master
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 74.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 6.3 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/rail-berkeley/d4rl (to revision master) to /tmp/pip-req-build-3b3a7g67
#   Running command git clone --filter=blob:none --quiet https://github.com/rail-berkeley/d4rl /tmp/pip-req-build-3b3a7g67
#   Resolved https://github.com/rail-berkeley/d4rl to commit 71a9549f2091accff93eeff68f1f3ab2c0e0a288
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/aravindr93/mjrl (to revision master) to /tmp/pip-install-39i98a2c/mjrl_4d2ab34b4e6b48fdb1f3a144ecab1850
#   Running command git clone --filter=blob:none --quiet https://github.com/aravindr93/mjrl /tmp/pip-install-39i98a2c/mjrl_4d2ab34b4e6b48fdb1f3a144ecab1850
# ...

# %% [markdown]
# # run

# %%
# !python3 /content/gdrive/MyDrive/IDQL_main/launcher/examples/train_ddpm_iql_offline.py --variant 0 N
# Out:
# 2024-06-09 09:04:22.395695: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 09:04:22.395765: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 09:04:22.399248: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-09 09:04:23.815300: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# You appear to be missing MuJoCo.  We expected to find the file here: /root/.mujoco/mujoco210
#
# This package only provides python bindings, the library must be installed separately.
#
# ...

# %%
# !apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common
# !apt-get install -y patchelf
# !pip install free-mujoco-py
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libglew-dev is already the newest version (2.2.0-4).
# libgl1-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# libosmesa6-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# software-properties-common is already the newest version (0.99.22.9).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# patchelf is already the newest version (0.14.3-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
